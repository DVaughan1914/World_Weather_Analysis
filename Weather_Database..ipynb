# %%
#Import the dependecies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Creat a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lats_lngs = zip(lats,lngs)
lats_lngs

# %%
#Add the latitudes and longitudes to a list
coordinates = list(lats_lngs)

# %%
#Import citipy module
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 712

# %%
#Import the time libary and the datatime module from the datatime libaruy
import time
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from Config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7d9f32f8c6fad2f22ebd04a2fc0f1921

# %%
#Create an empty list to hold the weather data
city_data = []
#Print the begining of the logging
print("Beginning Data Retrieval   ")
print("---------------------------")

#Create counters
record_count = 1
set_count = 1


# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

 # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_descrip = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": weather_descrip})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ---------------------------
# Processing Record 1 of Set 1 | piet retief
# Processing Record 2 of Set 1 | komsomolskiy
# Processing Record 3 of Set 1 | hilo
# Processing Record 4 of Set 1 | kapaa
# Processing Record 5 of Set 1 | suntar
# Processing Record 6 of Set 1 | avarua
# Processing Record 7 of Set 1 | qaanaaq
# Processing Record 8 of Set 1 | abapo
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | gobabis
# Processing Record 11 of Set 1 | hobart
# Processing Record 12 of Set 1 | thompson
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | raga
# Processing Record 15 of Set 1 | iqaluit
# Processing Record 16 of Set 1 | tuktoyaktuk
# Processing Record 17 of Set 1 | puerto ayora
# Processing Record 18 of Set 1 | nguiu
# City not found. Skipping...
# Processing Record 19 of Set 1 | kaihua
# Processing Record 20 of Set 1 | bolobo
# Processing Record 21 of Set 1 | punta arenas
# Processing Record 22 of Set 1 | morondava
# Processing Record 23 of Set 1 | westport
# Processing Record 24 of Set 1 | katubao
# Processing Record 25 of Set 1 | busselton
# Processing Record 26 of Set 1 | solovetskiy
# City not found. Skipping...
# Processing Record 27 of Set 1 | tonantins
# Processing Record 28 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 1 | yellowknife
# Processing Record 30 of Set 1 | buraydah
# Processing Record 31 of Set 1 | shelburne
# Processing Record 32 of Set 1 | ribeira grande
# Processing Record 33 of Set 1 | mataura
# Processing Record 34 of Set 1 | ancud
# Processing Record 35 of Set 1 | port alfred
# Processing Record 36 of Set 1 | abha
# Processing Record 37 of Set 1 | lebu
# Processing Record 38 of Set 1 | ambulu
# Processing Record 39 of Set 1 | saint-philippe
# Processing Record 40 of Set 1 | ponnani
# Processing Record 41 of Set 1 | rikitea
# Processing Record 42 of Set 1 | mahebourg
# Processing Record 43 of Set 1 | tasiilaq
# Processing Record 44 of Set 1 | kaabong
# Processing Record 45 of Set 1 | mar del plata
# Processing Record 46 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 1 | beberibe
# Processing Record 48 of Set 1 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 49 of Set 1 | banjar
# Processing Record 50 of Set 1 | pevek
# Processing Record 1 of Set 2 | hermanus
# Processing Record 2 of Set 2 | cape town
# Processing Record 3 of Set 2 | carnarvon
# Processing Record 4 of Set 2 | atar
# Processing Record 5 of Set 2 | moron
# Processing Record 6 of Set 2 | severo-kurilsk
# Processing Record 7 of Set 2 | castro
# Processing Record 8 of Set 2 | krasnoselkup
# Processing Record 9 of Set 2 | fraga
# Processing Record 10 of Set 2 | mumias
# Processing Record 11 of Set 2 | sioux lookout
# Processing Record 12 of Set 2 | east london
# Processing Record 13 of Set 2 | kahului
# Processing Record 14 of Set 2 | aguascalientes
# Processing Record 15 of Set 2 | lewiston
# Processing Record 16 of Set 2 | pangnirtung
# Processing Record 17 of Set 2 | manali
# Processing Record 18 of Set 2 | saskylakh
# Processing Record 19 of Set 2 | karamadai
# Processing Record 20 of Set 2 | caravelas
# Processing Record 21 of Set 2 | suicheng
# Processing Record 22 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 2 | norman wells
# Processing Record 24 of Set 2 | atuona
# Processing Record 25 of Set 2 | shingu
# Processing Record 26 of Set 2 | bluff
# Processing Record 27 of Set 2 | bhindar
# Processing Record 28 of Set 2 | guerrero negro
# Processing Record 29 of Set 2 | torbay
# Processing Record 30 of Set 2 | stornoway
# Processing Record 31 of Set 2 | vila velha
# Processing Record 32 of Set 2 | portland
# Processing Record 33 of Set 2 | jamestown
# Processing Record 34 of Set 2 | katsuura
# Processing Record 35 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 2 | santa rosa
# Processing Record 37 of Set 2 | lavrentiya
# Processing Record 38 of Set 2 | chicama
# Processing Record 39 of Set 2 | palana
# Processing Record 40 of Set 2 | cidreira
# Processing Record 41 of Set 2 | bredasdorp
# Processing Record 42 of Set 2 | dogondoutchi
# Processing Record 43 of Set 2 | erzin
# Processing Record 44 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 45 of Set 2 | haines junction
# Processing Record 46 of Set 2 | ahipara
# Processing Record 47 of Set 2 | yumen
# Processing Record 48 of Set 2 | koroni
# Processing Record 49 of Set 2 | rawson
# Processing Record 50 of Set 2 | sao filipe
# Processing Record 1 of Set 3 | muroto
# Processing Record 2 of Set 3 | tuatapere
# Processing Record 3 of Set 3 | vaini
# Processing Record 4 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 3 | dikson
# Processing Record 6 of Set 3 | malyn
# Processing Record 7 of Set 3 | longyearbyen
# Processing Record 8 of Set 3 | vanavara
# Processing Record 9 of Set 3 | kandrian
# Processing Record 10 of Set 3 | kokstad
# Processing Record 11 of Set 3 | butaritari
# Processing Record 12 of Set 3 | daru
# Processing Record 13 of Set 3 | mocajuba
# Processing Record 14 of Set 3 | flinders
# Processing Record 15 of Set 3 | cherskiy
# Processing Record 16 of Set 3 | vardo
# Processing Record 17 of Set 3 | kuloy
# Processing Record 18 of Set 3 | mareeba
# Processing Record 19 of Set 3 | tuma
# Processing Record 20 of Set 3 | bhunya
# Processing Record 21 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 22 of Set 3 | nikolskoye
# Processing Record 23 of Set 3 | jiddah
# City not found. Skipping...
# Processing Record 24 of Set 3 | georgetown
# Processing Record 25 of Set 3 | homer
# Processing Record 26 of Set 3 | port elizabeth
# Processing Record 27 of Set 3 | general roca
# Processing Record 28 of Set 3 | saint george
# Processing Record 29 of Set 3 | clyde river
# Processing Record 30 of Set 3 | faanui
# Processing Record 31 of Set 3 | aybak
# City not found. Skipping...
# Processing Record 32 of Set 3 | karratha
# Processing Record 33 of Set 3 | leningradskiy
# Processing Record 34 of Set 3 | maragogi
# Processing Record 35 of Set 3 | celestun
# Processing Record 36 of Set 3 | matagami
# Processing Record 37 of Set 3 | lasa
# Processing Record 38 of Set 3 | airai
# Processing Record 39 of Set 3 | majene
# Processing Record 40 of Set 3 | new norfolk
# Processing Record 41 of Set 3 | oriximina
# Processing Record 42 of Set 3 | san quintin
# Processing Record 43 of Set 3 | hualmay
# Processing Record 44 of Set 3 | vila franca do campo
# Processing Record 45 of Set 3 | ankazoabo
# Processing Record 46 of Set 3 | vao
# Processing Record 47 of Set 3 | isangel
# Processing Record 48 of Set 3 | talnakh
# Processing Record 49 of Set 3 | souillac
# Processing Record 50 of Set 3 | khatanga
# Processing Record 1 of Set 4 | vestmanna
# Processing Record 2 of Set 4 | pisco
# Processing Record 3 of Set 4 | kenora
# Processing Record 4 of Set 4 | barrow
# Processing Record 5 of Set 4 | hithadhoo
# Processing Record 6 of Set 4 | margate
# Processing Record 7 of Set 4 | paamiut
# Processing Record 8 of Set 4 | yulara
# Processing Record 9 of Set 4 | constitucion
# Processing Record 10 of Set 4 | dieppe
# Processing Record 11 of Set 4 | topeka
# Processing Record 12 of Set 4 | touros
# Processing Record 13 of Set 4 | kaitangata
# Processing Record 14 of Set 4 | chokurdakh
# Processing Record 15 of Set 4 | kirovskiy
# Processing Record 16 of Set 4 | bilma
# Processing Record 17 of Set 4 | suzu
# City not found. Skipping...
# Processing Record 18 of Set 4 | shitanjing
# Processing Record 19 of Set 4 | meshchovsk
# Processing Record 20 of Set 4 | kurumkan
# Processing Record 21 of Set 4 | bambous virieux
# Processing Record 22 of Set 4 | bosaso
# Processing Record 23 of Set 4 | iowa city
# Processing Record 24 of Set 4 | cabo san lucas
# Processing Record 25 of Set 4 | syasstroy
# Processing Record 26 of Set 4 | tete
# Processing Record 27 of Set 4 | provideniya
# Processing Record 28 of Set 4 | whitianga
# Processing Record 29 of Set 4 | lengshuitan
# Processing Record 30 of Set 4 | kasongo-lunda
# Processing Record 31 of Set 4 | adrar
# Processing Record 32 of Set 4 | dokka
# Processing Record 33 of Set 4 | richards bay
# Processing Record 34 of Set 4 | dicabisagan
# Processing Record 35 of Set 4 | cheuskiny
# City not found. Skipping...
# Processing Record 36 of Set 4 | la ronge
# Processing Record 37 of Set 4 | steamboat springs
# Processing Record 38 of Set 4 | namibe
# Processing Record 39 of Set 4 | poum
# Processing Record 40 of Set 4 | ponta do sol
# Processing Record 41 of Set 4 | mulchen
# Processing Record 42 of Set 4 | ilulissat
# Processing Record 43 of Set 4 | cambrils
# Processing Record 44 of Set 4 | sao joao da barra
# Processing Record 45 of Set 4 | ca mau
# Processing Record 46 of Set 4 | aljojuca
# Processing Record 47 of Set 4 | longlac
# City not found. Skipping...
# Processing Record 48 of Set 4 | kirkuk
# Processing Record 49 of Set 4 | bandarbeyla
# Processing Record 50 of Set 4 | vestbygda
# City not found. Skipping...
# Processing Record 1 of Set 5 | pulandian
# Processing Record 2 of Set 5 | tagusao
# Processing Record 3 of Set 5 | tongren
# Processing Record 4 of Set 5 | tiksi
# Processing Record 5 of Set 5 | ziro
# Processing Record 6 of Set 5 | arraial do cabo
# Processing Record 7 of Set 5 | chor
# Processing Record 8 of Set 5 | zyryanka
# Processing Record 9 of Set 5 | kruisfontein
# Processing Record 10 of Set 5 | miri
# Processing Record 11 of Set 5 | cerritos
# Processing Record 12 of Set 5 | kaohsiung
# Processing Record 13 of Set 5 | kodiak
# Processing Record 14 of Set 5 | astana
# Processing Record 15 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 16 of Set 5 | wahiawa
# Processing Record 17 of Set 5 | walvis bay
# Processing Record 18 of Set 5 | virginia beach
# Processing Record 19 of Set 5 | upernavik
# Processing Record 20 of Set 5 | yerbogachen
# Processing Record 21 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 5 | esperance
# Processing Record 23 of Set 5 | chuy
# Processing Record 24 of Set 5 | los llanos de aridane
# Processing Record 25 of Set 5 | lianran
# Processing Record 26 of Set 5 | bengkulu
# Processing Record 27 of Set 5 | west lafayette
# Processing Record 28 of Set 5 | kavieng
# Processing Record 29 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 5 | aswan
# Processing Record 31 of Set 5 | belaya gora
# Processing Record 32 of Set 5 | egvekinot
# Processing Record 33 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 34 of Set 5 | padang
# Processing Record 35 of Set 5 | chernyshevskiy
# Processing Record 36 of Set 5 | cedar city
# Processing Record 37 of Set 5 | bethanien
# Processing Record 38 of Set 5 | nome
# Processing Record 39 of Set 5 | saint anthony
# Processing Record 40 of Set 5 | narsaq
# Processing Record 41 of Set 5 | kieta
# Processing Record 42 of Set 5 | comonfort
# Processing Record 43 of Set 5 | aykhal
# Processing Record 44 of Set 5 | port hedland
# Processing Record 45 of Set 5 | ulladulla
# Processing Record 46 of Set 5 | viransehir
# Processing Record 47 of Set 5 | booue
# Processing Record 48 of Set 5 | xinzhou
# Processing Record 49 of Set 5 | solnechnyy
# Processing Record 50 of Set 5 | morro bay
# Processing Record 1 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 6 | luderitz
# Processing Record 3 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 6 | michigan city
# Processing Record 5 of Set 6 | high level
# Processing Record 6 of Set 6 | korla
# Processing Record 7 of Set 6 | ozgon
# City not found. Skipping...
# Processing Record 8 of Set 6 | paita
# Processing Record 9 of Set 6 | college
# Processing Record 10 of Set 6 | sitka
# Processing Record 11 of Set 6 | daye
# Processing Record 12 of Set 6 | manta
# Processing Record 13 of Set 6 | valdivia
# Processing Record 14 of Set 6 | wanning
# Processing Record 15 of Set 6 | camacha
# Processing Record 16 of Set 6 | ordubad
# Processing Record 17 of Set 6 | rawannawi
# City not found. Skipping...
# Processing Record 18 of Set 6 | grafton
# Processing Record 19 of Set 6 | songjianghe
# Processing Record 20 of Set 6 | husavik
# Processing Record 21 of Set 6 | nishihara
# Processing Record 22 of Set 6 | bad tolz
# Processing Record 23 of Set 6 | port hardy
# Processing Record 24 of Set 6 | mathbaria
# Processing Record 25 of Set 6 | dovers
# Processing Record 26 of Set 6 | viedma
# Processing Record 27 of Set 6 | key west
# Processing Record 28 of Set 6 | timmins
# Processing Record 29 of Set 6 | port blair
# Processing Record 30 of Set 6 | sistranda
# Processing Record 31 of Set 6 | geraldton
# Processing Record 32 of Set 6 | tulagi
# Processing Record 33 of Set 6 | plettenberg bay
# Processing Record 34 of Set 6 | orangeburg
# Processing Record 35 of Set 6 | billings
# Processing Record 36 of Set 6 | dingle
# Processing Record 37 of Set 6 | alofi
# Processing Record 38 of Set 6 | hearst
# Processing Record 39 of Set 6 | necochea
# Processing Record 40 of Set 6 | lorengau
# Processing Record 41 of Set 6 | san policarpo
# Processing Record 42 of Set 6 | ignalina
# Processing Record 43 of Set 6 | udachnyy
# Processing Record 44 of Set 6 | victoria
# Processing Record 45 of Set 6 | sola
# Processing Record 46 of Set 6 | buckeye
# Processing Record 47 of Set 6 | bathsheba
# Processing Record 48 of Set 6 | opunake
# Processing Record 49 of Set 6 | halvad
# Processing Record 50 of Set 6 | najran
# Processing Record 1 of Set 7 | tangjiazhuang
# Processing Record 2 of Set 7 | minab
# Processing Record 3 of Set 7 | huarmey
# Processing Record 4 of Set 7 | giyon
# Processing Record 5 of Set 7 | riyadh
# Processing Record 6 of Set 7 | koosa
# Processing Record 7 of Set 7 | naze
# Processing Record 8 of Set 7 | saint-joseph
# Processing Record 9 of Set 7 | wajima
# Processing Record 10 of Set 7 | lexington
# Processing Record 11 of Set 7 | taiyuan
# Processing Record 12 of Set 7 | sysert
# Processing Record 13 of Set 7 | gejiu
# Processing Record 14 of Set 7 | dolbeau
# City not found. Skipping...
# Processing Record 15 of Set 7 | hasaki
# Processing Record 16 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 17 of Set 7 | kuryk
# Processing Record 18 of Set 7 | uige
# Processing Record 19 of Set 7 | orsk
# Processing Record 20 of Set 7 | kloulklubed
# Processing Record 21 of Set 7 | vitoria do mearim
# Processing Record 22 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 7 | san vicente
# Processing Record 24 of Set 7 | fort nelson
# Processing Record 25 of Set 7 | amboasary
# Processing Record 26 of Set 7 | sidney
# Processing Record 27 of Set 7 | altamira
# Processing Record 28 of Set 7 | kaura namoda
# Processing Record 29 of Set 7 | cayenne
# Processing Record 30 of Set 7 | uyemskiy
# Processing Record 31 of Set 7 | ola
# Processing Record 32 of Set 7 | puerto escondido
# Processing Record 33 of Set 7 | filadelfia
# Processing Record 34 of Set 7 | carauari
# Processing Record 35 of Set 7 | drezdenko
# Processing Record 36 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 37 of Set 7 | roanoke
# Processing Record 38 of Set 7 | tambacounda
# Processing Record 39 of Set 7 | hay river
# Processing Record 40 of Set 7 | watsa
# Processing Record 41 of Set 7 | damaturu
# Processing Record 42 of Set 7 | saskatoon
# Processing Record 43 of Set 7 | pombas
# Processing Record 44 of Set 7 | voh
# Processing Record 45 of Set 7 | kalmunai
# Processing Record 46 of Set 7 | avera
# Processing Record 47 of Set 7 | baruun-urt
# Processing Record 48 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 49 of Set 7 | bethel
# Processing Record 50 of Set 7 | rolim de moura
# City not found. Skipping...
# Processing Record 1 of Set 8 | mporokoso
# Processing Record 2 of Set 8 | arkhara
# Processing Record 3 of Set 8 | mineiros
# Processing Record 4 of Set 8 | minsk
# Processing Record 5 of Set 8 | bajo baudo
# City not found. Skipping...
# Processing Record 6 of Set 8 | algiers
# Processing Record 7 of Set 8 | vityazevo
# Processing Record 8 of Set 8 | saldanha
# Processing Record 9 of Set 8 | lagoa
# Processing Record 10 of Set 8 | verona
# Processing Record 11 of Set 8 | barcelos
# Processing Record 12 of Set 8 | berkak
# Processing Record 13 of Set 8 | shellbrook
# Processing Record 14 of Set 8 | kaeo
# Processing Record 15 of Set 8 | sambava
# Processing Record 16 of Set 8 | san miguel el alto
# Processing Record 17 of Set 8 | tessaoua
# Processing Record 18 of Set 8 | sibu
# Processing Record 19 of Set 8 | samarai
# Processing Record 20 of Set 8 | ifanadiana
# Processing Record 21 of Set 8 | henties bay
# Processing Record 22 of Set 8 | tasbuget
# City not found. Skipping...
# Processing Record 23 of Set 8 | quatre cocos
# Processing Record 24 of Set 8 | asilah
# Processing Record 25 of Set 8 | katangli
# Processing Record 26 of Set 8 | maloshuyka
# City not found. Skipping...
# Processing Record 27 of Set 8 | tubruq
# City not found. Skipping...
# Processing Record 28 of Set 8 | puerto del rosario
# Processing Record 29 of Set 8 | yerofey pavlovich
# Processing Record 30 of Set 8 | bilibino
# Processing Record 31 of Set 8 | calvinia
# Processing Record 32 of Set 8 | candawaga
# City not found. Skipping...
# Processing Record 33 of Set 8 | klaksvik
# Processing Record 34 of Set 8 | fairbanks
# Processing Record 35 of Set 8 | kracheh
# City not found. Skipping...
# Processing Record 36 of Set 8 | san patricio
# Processing Record 37 of Set 8 | vagay
# Processing Record 38 of Set 8 | ayan
# Processing Record 39 of Set 8 | kristinehamn
# Processing Record 40 of Set 8 | tchaourou
# Processing Record 41 of Set 8 | bagdarin
# Processing Record 42 of Set 8 | lazaro cardenas
# Processing Record 43 of Set 8 | elizabeth city
# Processing Record 44 of Set 8 | bhan
# Processing Record 45 of Set 8 | barstow
# Processing Record 46 of Set 8 | belaguntha
# Processing Record 47 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 8 | burnie
# Processing Record 49 of Set 8 | rogers
# Processing Record 50 of Set 8 | verkhnyaya toyma
# Processing Record 1 of Set 9 | marrakesh
# Processing Record 2 of Set 9 | salou
# Processing Record 3 of Set 9 | broome
# Processing Record 4 of Set 9 | sechura
# Processing Record 5 of Set 9 | sereflikochisar
# Processing Record 6 of Set 9 | ugoofaaru
# Processing Record 7 of Set 9 | nanortalik
# Processing Record 8 of Set 9 | oussouye
# Processing Record 9 of Set 9 | bayreuth
# Processing Record 10 of Set 9 | oranjemund
# Processing Record 11 of Set 9 | bom jesus
# Processing Record 12 of Set 9 | port said
# Processing Record 13 of Set 9 | russell
# Processing Record 14 of Set 9 | lumeje
# Processing Record 15 of Set 9 | santa isabel do rio negro
# Processing Record 16 of Set 9 | khonsa
# Processing Record 17 of Set 9 | brigantine
# Processing Record 18 of Set 9 | havre-saint-pierre
# Processing Record 19 of Set 9 | warrington
# Processing Record 20 of Set 9 | eenhana
# Processing Record 21 of Set 9 | salalah
# Processing Record 22 of Set 9 | leshukonskoye
# Processing Record 23 of Set 9 | guarda
# Processing Record 24 of Set 9 | kasempa
# Processing Record 25 of Set 9 | treinta y tres
# Processing Record 26 of Set 9 | miranda
# Processing Record 27 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 28 of Set 9 | macaboboni
# City not found. Skipping...
# Processing Record 29 of Set 9 | nelson bay
# Processing Record 30 of Set 9 | pyu
# Processing Record 31 of Set 9 | menongue
# Processing Record 32 of Set 9 | coquimbo
# Processing Record 33 of Set 9 | sassandra
# Processing Record 34 of Set 9 | harper
# Processing Record 35 of Set 9 | xai-xai
# Processing Record 36 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 9 | vanimo
# Processing Record 39 of Set 9 | west plains
# Processing Record 40 of Set 9 | kletskaya
# Processing Record 41 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 42 of Set 9 | luanda
# Processing Record 43 of Set 9 | eureka
# Processing Record 44 of Set 9 | warrenton
# Processing Record 45 of Set 9 | broken hill
# Processing Record 46 of Set 9 | lazeshchyna
# Processing Record 47 of Set 9 | conde
# Processing Record 48 of Set 9 | moose factory
# Processing Record 49 of Set 9 | edgewater
# Processing Record 50 of Set 9 | kargil
# Processing Record 1 of Set 10 | meiganga
# Processing Record 2 of Set 10 | dwarka
# Processing Record 3 of Set 10 | kostomuksha
# Processing Record 4 of Set 10 | jaru
# Processing Record 5 of Set 10 | havelock
# Processing Record 6 of Set 10 | hokitika
# Processing Record 7 of Set 10 | churapcha
# Processing Record 8 of Set 10 | pahrump
# Processing Record 9 of Set 10 | mount isa
# Processing Record 10 of Set 10 | abu kamal
# Processing Record 11 of Set 10 | muti
# Processing Record 12 of Set 10 | surgut
# Processing Record 13 of Set 10 | malartic
# Processing Record 14 of Set 10 | winburg
# Processing Record 15 of Set 10 | vestmannaeyjar
# Processing Record 16 of Set 10 | tacuarembo
# Processing Record 17 of Set 10 | kasangulu
# Processing Record 18 of Set 10 | unity
# Processing Record 19 of Set 10 | sokoto
# Processing Record 20 of Set 10 | nemuro
# Processing Record 21 of Set 10 | berlevag
# Processing Record 22 of Set 10 | zhigansk
# Processing Record 23 of Set 10 | chimoio
# Processing Record 24 of Set 10 | yenagoa
# Processing Record 25 of Set 10 | acarau
# Processing Record 26 of Set 10 | lensk
# Processing Record 27 of Set 10 | pridonskoy
# Processing Record 28 of Set 10 | tabasalu
# Processing Record 29 of Set 10 | gummidipundi
# Processing Record 30 of Set 10 | sur
# Processing Record 31 of Set 10 | escanaba
# Processing Record 32 of Set 10 | hamilton
# Processing Record 33 of Set 10 | banda aceh
# Processing Record 34 of Set 10 | kerman
# Processing Record 35 of Set 10 | rocha
# Processing Record 36 of Set 10 | kunya
# Processing Record 37 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 38 of Set 10 | scarborough
# Processing Record 39 of Set 10 | varhaug
# Processing Record 40 of Set 10 | panzhihua
# Processing Record 41 of Set 10 | beloha
# Processing Record 42 of Set 10 | quelimane
# Processing Record 43 of Set 10 | kirakira
# Processing Record 44 of Set 10 | pangody
# Processing Record 45 of Set 10 | wagar
# Processing Record 46 of Set 10 | omboue
# Processing Record 47 of Set 10 | kodino
# Processing Record 48 of Set 10 | sao miguel do araguaia
# Processing Record 49 of Set 10 | la union
# Processing Record 50 of Set 10 | delmas
# Processing Record 1 of Set 11 | sabang
# Processing Record 2 of Set 11 | abu dhabi
# Processing Record 3 of Set 11 | srednekolymsk
# Processing Record 4 of Set 11 | bossangoa
# Processing Record 5 of Set 11 | talara
# Processing Record 6 of Set 11 | karauzyak
# City not found. Skipping...
# Processing Record 7 of Set 11 | griffith
# Processing Record 8 of Set 11 | san javier
# Processing Record 9 of Set 11 | porto walter
# Processing Record 10 of Set 11 | begoro
# Processing Record 11 of Set 11 | ngatea
# Processing Record 12 of Set 11 | grand-santi
# Processing Record 13 of Set 11 | ojinaga
# Processing Record 14 of Set 11 | porbandar
# Processing Record 15 of Set 11 | manokwari
# Processing Record 16 of Set 11 | uyskoye
# Processing Record 17 of Set 11 | berea
# Processing Record 18 of Set 11 | port lincoln
# Processing Record 19 of Set 11 | comodoro rivadavia
# Processing Record 20 of Set 11 | codrington
# Processing Record 21 of Set 11 | fortuna
# Processing Record 22 of Set 11 | athenry
# Processing Record 23 of Set 11 | chingirlau
# Processing Record 24 of Set 11 | plerin
# Processing Record 25 of Set 11 | hampton
# Processing Record 26 of Set 11 | hecun
# Processing Record 27 of Set 11 | dinsor
# City not found. Skipping...
# Processing Record 28 of Set 11 | zhelyabovka
# Processing Record 29 of Set 11 | santa helena de goias
# Processing Record 30 of Set 11 | mamakan
# Processing Record 31 of Set 11 | half moon bay
# Processing Record 32 of Set 11 | clinton
# Processing Record 33 of Set 11 | vire
# Processing Record 34 of Set 11 | temaraia
# City not found. Skipping...
# Processing Record 35 of Set 11 | austin
# Processing Record 36 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 37 of Set 11 | berdigestyakh
# Processing Record 38 of Set 11 | tura
# Processing Record 39 of Set 11 | upata
# Processing Record 40 of Set 11 | tual
# Processing Record 41 of Set 11 | hobyo
# Processing Record 42 of Set 11 | dudinka
# Processing Record 43 of Set 11 | samfya
# Processing Record 44 of Set 11 | emerald
# Processing Record 45 of Set 11 | zhuozhou
# City not found. Skipping...
# Processing Record 46 of Set 11 | nhamunda
# Processing Record 47 of Set 11 | senden
# Processing Record 48 of Set 11 | kentville
# Processing Record 49 of Set 11 | nabire
# Processing Record 50 of Set 11 | katherine
# Processing Record 1 of Set 12 | onguday
# Processing Record 2 of Set 12 | liverpool
# Processing Record 3 of Set 12 | monte carmelo
# Processing Record 4 of Set 12 | isilkul
# Processing Record 5 of Set 12 | north myrtle beach
# Processing Record 6 of Set 12 | maturin
# Processing Record 7 of Set 12 | thiruvananthapuram
# Processing Record 8 of Set 12 | geresk
# City not found. Skipping...
# Processing Record 9 of Set 12 | ulverstone
# Processing Record 10 of Set 12 | carballo
# Processing Record 11 of Set 12 | roald
# Processing Record 12 of Set 12 | morant bay
# Processing Record 13 of Set 12 | lompoc
# Processing Record 14 of Set 12 | greer
# Processing Record 15 of Set 12 | goma
# Processing Record 16 of Set 12 | mecca
# Processing Record 17 of Set 12 | epinal
# Processing Record 18 of Set 12 | puerto leguizamo
# Processing Record 19 of Set 12 | pundaguitan
# Processing Record 20 of Set 12 | kavaratti
# Processing Record 21 of Set 12 | montepuez
# Processing Record 22 of Set 12 | solwezi
# Processing Record 23 of Set 12 | hambantota
# Processing Record 24 of Set 12 | karakol
# Processing Record 25 of Set 12 | abu jubayhah
# City not found. Skipping...
# Processing Record 26 of Set 12 | carutapera
# Processing Record 27 of Set 12 | pacific grove
# Processing Record 28 of Set 12 | eston
# Processing Record 29 of Set 12 | daloa
# Processing Record 30 of Set 12 | whitehorse
# Processing Record 31 of Set 12 | nizhniy ingash
# Processing Record 32 of Set 12 | pionki
# Processing Record 33 of Set 12 | sovetskiy
# Processing Record 34 of Set 12 | rio grande
# Processing Record 35 of Set 12 | muisne
# Processing Record 36 of Set 12 | omsukchan
# Processing Record 37 of Set 12 | santa maria
# Processing Record 38 of Set 12 | gold coast
# Processing Record 39 of Set 12 | bonavista
# Processing Record 40 of Set 12 | eyl
# Processing Record 41 of Set 12 | loucovice
# Processing Record 42 of Set 12 | clovis
# Processing Record 43 of Set 12 | la tuque
# Processing Record 44 of Set 12 | cowra
# Processing Record 45 of Set 12 | monroe
# Processing Record 46 of Set 12 | dunedin
# Processing Record 47 of Set 12 | luohe
# Processing Record 48 of Set 12 | malindi
# Processing Record 49 of Set 12 | tomatlan
# Processing Record 50 of Set 12 | lodwar
# Processing Record 1 of Set 13 | kurilsk
# Processing Record 2 of Set 13 | taltal
# Processing Record 3 of Set 13 | kenai
# Processing Record 4 of Set 13 | tobol
# Processing Record 5 of Set 13 | atherton
# Processing Record 6 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 13 | preobrazheniye
# Processing Record 8 of Set 13 | phan rang
# City not found. Skipping...
# Processing Record 9 of Set 13 | sisimiut
# Processing Record 10 of Set 13 | jiexiu
# Processing Record 11 of Set 13 | yatou
# Processing Record 12 of Set 13 | kushmurun
# Processing Record 13 of Set 13 | hervey bay
# Processing Record 14 of Set 13 | maraba
# Processing Record 15 of Set 13 | fereydun kenar
# Processing Record 16 of Set 13 | san clemente
# Processing Record 17 of Set 13 | bubaque
# Processing Record 18 of Set 13 | gimli
# Processing Record 19 of Set 13 | henzada
# City not found. Skipping...
# Processing Record 20 of Set 13 | snasa
# Processing Record 21 of Set 13 | salinopolis
# Processing Record 22 of Set 13 | sao jose da coroa grande
# Processing Record 23 of Set 13 | shenjiamen
# Processing Record 24 of Set 13 | wainwright
# Processing Record 25 of Set 13 | maridi
# Processing Record 26 of Set 13 | wuwei
# Processing Record 27 of Set 13 | dickinson
# Processing Record 28 of Set 13 | peniche
# Processing Record 29 of Set 13 | ust-abakan
# Processing Record 30 of Set 13 | sherwood
# Processing Record 31 of Set 13 | saint-pierre
# Processing Record 32 of Set 13 | livingstone
# Processing Record 33 of Set 13 | tres arroyos
# Processing Record 34 of Set 13 | olinda
# Processing Record 35 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 36 of Set 13 | milledgeville
# Processing Record 37 of Set 13 | evensk
# Processing Record 38 of Set 13 | usta muhammad
# Processing Record 39 of Set 13 | boyolangu
# Processing Record 40 of Set 13 | burkhala
# City not found. Skipping...
# Processing Record 41 of Set 13 | andros town
# Processing Record 42 of Set 13 | kodinsk
# Processing Record 43 of Set 13 | beringovskiy
# Processing Record 44 of Set 13 | inirida
# Processing Record 45 of Set 13 | ledec
# Processing Record 46 of Set 13 | zhenlai
# Processing Record 47 of Set 13 | andra
# Processing Record 48 of Set 13 | esna
# Processing Record 49 of Set 13 | todi
# Processing Record 50 of Set 13 | magaria
# Processing Record 1 of Set 14 | cucuyagua
# Processing Record 2 of Set 14 | tokmak
# Processing Record 3 of Set 14 | qaqortoq
# Processing Record 4 of Set 14 | darayya
# Processing Record 5 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 6 of Set 14 | north bend
# Processing Record 7 of Set 14 | laukaa
# Processing Record 8 of Set 14 | goba
# Processing Record 9 of Set 14 | goderich
# Processing Record 10 of Set 14 | haibowan
# City not found. Skipping...
# Processing Record 11 of Set 14 | keetmanshoop
# Processing Record 12 of Set 14 | matina
# Processing Record 13 of Set 14 | jodhpur
# Processing Record 14 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 15 of Set 14 | tineo
# Processing Record 16 of Set 14 | vallenar
# Processing Record 17 of Set 14 | mackay
# Processing Record 18 of Set 14 | aberdeen
# Processing Record 19 of Set 14 | charlottetown
# Processing Record 20 of Set 14 | mnogovershinnyy
# Processing Record 21 of Set 14 | la romana
# Processing Record 22 of Set 14 | pilani
# Processing Record 23 of Set 14 | hami
# Processing Record 24 of Set 14 | tocopilla
# Processing Record 25 of Set 14 | mayya
# Processing Record 26 of Set 14 | bandipur
# Processing Record 27 of Set 14 | araouane
# Processing Record 28 of Set 14 | kiama
# Processing Record 29 of Set 14 | aklavik
# Processing Record 30 of Set 14 | canela
# Processing Record 31 of Set 14 | new ulm
# Processing Record 32 of Set 14 | borogontsy
# Processing Record 33 of Set 14 | petropavlovka
# Processing Record 34 of Set 14 | villazon
# Processing Record 35 of Set 14 | conceicao da barra
# Processing Record 36 of Set 14 | socorro
# Processing Record 37 of Set 14 | okhtyrka
# Processing Record 38 of Set 14 | kulhudhuffushi
# Processing Record 39 of Set 14 | tigil
# Processing Record 40 of Set 14 | palmer
# Processing Record 41 of Set 14 | buala
# Processing Record 42 of Set 14 | leh
# Processing Record 43 of Set 14 | krasnoyarskaya
# Processing Record 44 of Set 14 | maamba
# Processing Record 45 of Set 14 | verkhnyaya inta
# Processing Record 46 of Set 14 | qandala
# Processing Record 47 of Set 14 | pinhao
# Processing Record 48 of Set 14 | soubre
# Processing Record 49 of Set 14 | zile
# Processing Record 50 of Set 14 | mpika
# Processing Record 1 of Set 15 | sabirabad
# Processing Record 2 of Set 15 | baykit
# Processing Record 3 of Set 15 | pedasi
# Processing Record 4 of Set 15 | shimoga
# Processing Record 5 of Set 15 | sangar
# Processing Record 6 of Set 15 | cockburn harbour
# City not found. Skipping...
# Processing Record 7 of Set 15 | kudahuvadhoo
# Processing Record 8 of Set 15 | noumea
# Processing Record 9 of Set 15 | mangan
# Processing Record 10 of Set 15 | bacolod
# Processing Record 11 of Set 15 | villa rica
# Processing Record 12 of Set 15 | toamasina
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Convert the array of dictonaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Piet Retief -27.0071   30.8132     66.63        62           0
# 1  Komsomolskiy  40.4272   71.7189     56.12        58           0
# 2          Hilo  19.7297 -155.0900     69.53        91          75
# 3         Kapaa  22.0752 -159.3190     73.11        95          20
# 4        Suntar  62.1444  117.6319     30.06        97         100
# 5        Avarua -21.2078 -159.7750     75.25        94           6
# 6       Qaanaaq  77.4840  -69.3632     21.06        70          28
# 7         Abapo -18.8333  -63.4667     61.50        25         100
# 8       Ushuaia -54.8000  -68.3000     49.66        57          20
# 9       Gobabis -22.4500   18.9667     77.50        47          95
#
#    Wind Speed Country                 Date Current Description
# 0        5.73      ZA  2022-03-31 15:46:15           clear sky
# 1        4.61      UZ  2022-03-31 15:46:15           clear sky
# 2        5.75      US  2022-03-31 15:43:52       broken clouds
# 3       11.50      US  2022-03-31 15:42:58          few clouds
# 4        7.90      RU  2022-03-31 15:46:16          light snow
# 5        2.30      CK  2022-03-31 15:46:16           clear sky
# 6        6.89      GL  2022-03-31 15:46:16    scattered clouds
# 7        6.38      BO  2022-03-31 15:46:16     overcast clouds
# 8       13.80      AR  2022-03-31 15:41:30          few clouds
# 9       13.29      NA  2022-03-31 15:43:24     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
